# %% [markdown]
# @article{Pilgrim2021,
#          doi = {10.21105/joss.03859},
#          url = {https://doi.org/10.21105/joss.03859},
#          year = {2021}, publisher = {The Open Journal},
#          volume = {6},
#          number = {68},
#          pages = {3859},
#          author = {Charlie Pilgrim},
#          title = {piecewise-regression (aka segmented regression) in Python},
#          journal = {Journal of Open Source Software}
#         }

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import piecewise_regression

from reg import quicklook, break_regression

import reg.calc_utilities as calc


path = f"data{os.sep}"
filename = "phys_data_2023-03-12_side0.csv"

# %%
df = pd.read_csv(f"{path}{filename}", parse_dates=True, index_col="TimeUTC")

# %%
df
# Out:
#                        P1     P2    P3    P4     P5     P6     P7      P8  \
# TimeUTC
# 2023-03-12 00:00:00   0.0   0.00  0.00  0.00  0.000  0.000  0.000  0.0000
# 2023-03-12 00:00:24   0.0   0.00  0.00  0.00  0.000  0.000  0.000  0.0000
# 2023-03-12 00:00:48   0.0   0.00  0.00  0.00  0.000  0.000  0.000  0.0000
# 2023-03-12 00:01:12   0.0   0.00  0.00  0.00  0.000  0.000  0.000  0.0000
# 2023-03-12 00:01:36   0.0   0.00  0.00  0.00  0.000  0.000  0.000  0.0000
# ...                   ...    ...   ...   ...    ...    ...    ...     ...
# 2023-03-14 23:58:00  61.2   7.14  3.95  3.42  1.590  0.000  0.142  0.0671
# 2023-03-14 23:58:24  24.5  14.30  9.88  5.70  1.590  0.954  0.142  0.0671
# 2023-03-14 23:58:48  61.2  21.40  9.89  2.28  1.590  0.000  0.142  0.0671
# 2023-03-14 23:59:12  48.9  14.30  5.93  5.70  1.590  0.954  0.000  0.0671
# 2023-03-14 23:59:36  61.2   7.14  0.00  1.14  0.795  1.190  0.000  0.0000
#
#                          P9      E1      E2      E3     E4    E5     E6  \
# TimeUTC
# 2023-03-12 00:00:00  0.0000     0.0     0.0   11.40    0.0   0.0  0.000
# 2023-03-12 00:00:24  0.0144   167.0     0.0    7.58    0.0   0.0  0.000
# 2023-03-12 00:00:48  0.0000     0.0     0.0    0.00    0.0   0.0  0.627
# 2023-03-12 00:01:12  0.0000   112.0    17.6    0.00    0.0   0.0  0.313
# 2023-03-12 00:01:36  0.0000    55.8     0.0    0.00    0.0   0.0  0.000
# ...                     ...     ...     ...     ...    ...   ...    ...
# 2023-03-14 23:58:00  0.0144  7090.0  2200.0  865.00  325.0  10.5  0.314
# 2023-03-14 23:58:24  0.0000  5030.0  1920.0  819.00  309.0  21.0  0.000
# 2023-03-14 23:58:48  0.0000  6480.0  2360.0  895.00  262.0  16.8  0.314
# 2023-03-14 23:59:12  0.0000  6420.0  2390.0  895.00  325.0  14.7  0.000
# 2023-03-14 23:59:36  0.0000  6700.0  1810.0  827.00  325.0  23.1  0.627
#
#                         E7    DT          PA
# TimeUTC
# 2023-03-12 00:00:00  0.000  0.00   86.490453
# 2023-03-12 00:00:24  0.000  0.00   81.321720
# 2023-03-12 00:00:48  0.000  0.00   69.690026
# 2023-03-12 00:01:12  0.000  0.00   70.727876
# 2023-03-12 00:01:36  0.000  0.00   68.520445
# ...                    ...   ...         ...
# 2023-03-14 23:58:00  0.000  1.29  100.899747
# 2023-03-14 23:58:24  0.088  1.12   84.530333
# 2023-03-14 23:58:48  0.000  1.46   95.456014
# 2023-03-14 23:59:12  0.000  1.29  101.019541
# 2023-03-14 23:59:36  0.000  1.17  107.450316
#
# [10800 rows x 18 columns]

# %%
quicklook(data=df, channel="P4", resample=None)

# %% [markdown]
# ### piecewise-regression testing:

# %%
# The slope of the first line
alpha_1 = 0.5

# The slope of the second line
alpha_2 = 7

# The constant factor of the first line alpha_1 * x + C
constant = 12

# The point at which the gradient changes from alpha_1 to alpha_2
breakpoint_1 = 11

# The number of data points in consideration
n_points = 2000

# Setting the random seed for reproductibility
np.random.seed(0)

# The x-axis values, i.e., the independent variable
xx = np.linspace(0, 20, n_points)

# The dependent variable
yy = constant + alpha_1*xx + (alpha_2-alpha_1) * np.maximum(xx - breakpoint_1, 0) + np.random.normal(size=n_points)

# %%
# Prepare the figure visualizing the data
fig, ax = plt.subplots(figsize=(13,7))

ax.step(xx,yy, where="mid", c="grey")
#ax.scatter(xx,yy)

plt.show()

# %%
# Given some data, fit the model
pw_fit = piecewise_regression.Fit(xx, yy, start_values=[5], n_breakpoints=1)

# Print a summary of the fit
pw_fit.summary()
# Out:
#                     Breakpoint Regression Results
# ====================================================================================================
# No. Observations                     2000
# No. Model Parameters                    4
# Degrees of Freedom                   1996
# Res. Sum of Squares               1910.35
# Total Sum of Squares          8.84751e+05
# R Squared                        0.997841
# Adjusted R Squared               0.997836
# Converged:                           True
# ====================================================================================================
# ====================================================================================================
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const                11.9589        0.059       202.67           0.0       11.843       12.075
# alpha1              0.499759      0.00931        53.68           0.0       0.4815      0.51802
# beta1                6.48542       0.0156       416.02             -       6.4548        6.516
# breakpoint1          10.9804       0.0136            -             -       10.954       11.007
# ----------------------------------------------------------------------------------------------------
# These alphas(gradients of segments) are estimatedfrom betas(change in gradient)
# ----------------------------------------------------------------------------------------------------
# alpha2               6.98518       0.0125       558.65           0.0       6.9607       7.0097
# ====================================================================================================
# Davies test for existence of at least 1 breakpoint: p=0.0 (e.g. p<0.05 means reject null hypothesis of no breakpoints at 5% significance)
# '\n                    Breakpoint Regression Results                     \n====================================================================================================\nNo. Observations                     2000\nNo. Model Parameters                    4\nDegrees of Freedom                   1996\nRes. Sum of Squares               1910.35\nTotal Sum of Squares          8.84751e+05\nR Squared                        0.997841\nAdjusted R Squared               0.997836\nConverged:                           True\n====================================================================================================\n====================================================================================================\n                    Estimate      Std Err            t        P>|t|       [0.025       0.975]\n----------------------------------------------------------------------------------------------------\nconst                11.9589        0.059       202.67           0.0       11.843       12.075\nalpha1              0.499759      0.00931        53.68           0.0       0.4815      0.51802\nbeta1                6.48542       0.0156       416.02             -       6.4548        6.516\nbreakpoint1          10.9804       0.0136            -             -       10.954       11.007\n----------------------------------------------------------------------------------------------------\nThese alphas(gradients of segments) are estimatedfrom betas(change in gradient)\n----------------------------------------------------------------------------------------------------\nalpha2               6.98518       0.0125       558.65           0.0       6.9607       7.0097\n====================================================================================================\nDavies test for existence of at least 1 breakpoint: p=0.0 (e.g. p<0.05 means reject null hypothesis of no breakpoints at 5% significance)\n\n'

# %%
# Get the key results of the fit
pw_results = pw_fit.get_results()
pw_estimates = pw_results["estimates"]

# %%
pw_results
# Out:
# {'davies': np.float64(0.0),
#  'estimates': {'const': {'estimate': np.float64(11.95892145068034),
#    'se': np.float64(0.059007610826463185),
#    'confidence_interval': (np.float64(11.84319848553212),
#     np.float64(12.074644415828558)),
#    't_stat': np.float64(202.66744040613),
#    'p_t': np.float64(0.0)},
#   'beta1': {'estimate': np.float64(6.485421536556528),
#    'se': np.float64(0.01558903155915342),
#    'confidence_interval': (np.float64(6.454849057336519),
#     np.float64(6.515994015776537)),
#    't_stat': np.float64(416.0246588729548),
#    'p_t': '-'},
#   'breakpoint1': {'estimate': np.float64(10.980420870967645),
#    'se': np.float64(0.013557487007679007),
#    'confidence_interval': (np.float64(10.953832561857807),
#     np.float64(11.007009180077484)),
#    't_stat': '-',
#    'p_t': '-'},
#   'alpha1': {'estimate': np.float64(0.4997592260207653),
#    'se': np.float64(0.00930991848222239),
#    'confidence_interval': (np.float64(0.4815010495421506),
#     np.float64(0.5180174024993799)),
#    't_stat': np.float64(53.68030095806668),
#    'p_t': np.float64(0.0)},
#   'alpha2': {'estimate': np.float64(6.9851807625772935),
#    'se': np.float64(0.012503732355047243),
#    'confidence_interval': (np.float64(6.960659027782756),
#     np.float64(7.009702497371831)),
#    't_stat': np.float64(558.6476552945139),
#    'p_t': np.float64(0.0)}},
#  'bic': np.float64(-61.32164004391645),
#  'rss': np.float64(1910.3463402974435),
#  'converged': True}

# %%
pw_estimates
# Out:
# {'const': {'estimate': np.float64(11.95892145068034),
#   'se': np.float64(0.059007610826463185),
#   'confidence_interval': (np.float64(11.84319848553212),
#    np.float64(12.074644415828558)),
#   't_stat': np.float64(202.66744040613),
#   'p_t': np.float64(0.0)},
#  'beta1': {'estimate': np.float64(6.485421536556528),
#   'se': np.float64(0.01558903155915342),
#   'confidence_interval': (np.float64(6.454849057336519),
#    np.float64(6.515994015776537)),
#   't_stat': np.float64(416.0246588729548),
#   'p_t': '-'},
#  'breakpoint1': {'estimate': np.float64(10.980420870967645),
#   'se': np.float64(0.013557487007679007),
#   'confidence_interval': (np.float64(10.953832561857807),
#    np.float64(11.007009180077484)),
#   't_stat': '-',
#   'p_t': '-'},
#  'alpha1': {'estimate': np.float64(0.4997592260207653),
#   'se': np.float64(0.00930991848222239),
#   'confidence_interval': (np.float64(0.4815010495421506),
#    np.float64(0.5180174024993799)),
#   't_stat': np.float64(53.68030095806668),
#   'p_t': np.float64(0.0)},
#  'alpha2': {'estimate': np.float64(6.9851807625772935),
#   'se': np.float64(0.012503732355047243),
#   'confidence_interval': (np.float64(6.960659027782756),
#    np.float64(7.009702497371831)),
#   't_stat': np.float64(558.6476552945139),
#   'p_t': np.float64(0.0)}}

# %%
# Extract the results of fitting
estimated_const = pw_estimates["const"]["estimate"]
estimated_alpha_1 = pw_estimates["alpha1"]["estimate"]
estimated_alpha_2 = pw_estimates["alpha2"]["estimate"]

estimated_breakpoint = pw_estimates["breakpoint1"]["estimate"]
breakpoint_errs = pw_estimates["breakpoint1"]["confidence_interval"]

# %%
# Construct lines to show on the plot
line1 = xx*estimated_alpha_1 + estimated_const
line2 = xx*estimated_alpha_2 + np.nanmax(line1) - np.nanmax(yy)

# %%
# Plot the estimated values
ax.plot(xx, line1, ls="--", c="navy")
ax.plot(xx, line2, ls="--", c="navy")

ax.axvspan(xmin=breakpoint_errs[0], xmax=breakpoint_errs[1], alpha=0.25, color="red")
ax.axvline(x=estimated_breakpoint, c="red")

fig

# %%
ax.set_xlim(10,12)
fig

# %%
# Try the same but now with the P1 channel of previously downloaded data

# %%
# Intensities of P1 channel
ints = np.log10(df["P1"])
times = df.index.values
indices = np.linspace(start=0, stop=len(times)-1, num=len(times))
# Out:
# /home/chospa/anaconda3/envs/regs/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# First replace inf values with nan
ints.replace([np.inf, -np.inf], np.nan, inplace=True)

# Fill all nans with what comes after
filled_ints = ints.bfill()

# %%
filled_ints
# Out:
# TimeUTC
# 2023-03-12 00:00:00    1.086360
# 2023-03-12 00:00:24    1.086360
# 2023-03-12 00:00:48    1.086360
# 2023-03-12 00:01:12    1.086360
# 2023-03-12 00:01:36    1.086360
#                          ...
# 2023-03-14 23:58:00    1.786751
# 2023-03-14 23:58:24    1.389166
# 2023-03-14 23:58:48    1.786751
# 2023-03-14 23:59:12    1.689309
# 2023-03-14 23:59:36    1.786751
# Name: P1, Length: 10800, dtype: float64

# %%
first_peak, first_peak_idx = calc.search_first_peak(ints=filled_ints, threshold=2.5, window=100)
print(first_peak)
print(first_peak_idx)
# Out:
# 2.8356905714924254
# 5073

# %%
fig1, ax1 = plt.subplots(figsize=(13,7))

ax1.step(times, filled_ints)
#ax1.step(df.index, np.log10(df["P1"]))

ax1.axvspan(xmin=times[0], xmax=times[first_peak_idx], alpha=0.1, color="limegreen")

plt.show()

# %%
# Apply selection until the first peak
indices_sel = indices[:first_peak_idx]
ints_sel = filled_ints[:first_peak_idx]

# %%
fig2, ax2 = plt.subplots(figsize=(13,7))

ax2.step(indices_sel, ints_sel)
#ax2.scatter(indices_sel, ints_sel.values)

plt.show()

# %%
# Fit the model
p1_fit = piecewise_regression.Fit(indices_sel, ints_sel.values, start_values=[5], n_breakpoints=1)

# Print a summary of the fit
p1_fit.summary()
# Out:
#                     Breakpoint Regression Results
# ====================================================================================================
# No. Observations                     5073
# No. Model Parameters                    4
# Degrees of Freedom                   5069
# Res. Sum of Squares               53.4328
# Total Sum of Squares              555.791
# R Squared                        0.903862
# Adjusted R Squared               0.903786
# Converged:                           True
# ====================================================================================================
# ====================================================================================================
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const                1.07827      0.00318        339.2           0.0        1.072       1.0845
# alpha1           9.33084e-06     1.32e-06       7.0672       1.8e-12   6.7425e-06   1.1919e-05
# beta1             0.00149793     1.32e-05       113.52             -    0.0014721    0.0015238
# breakpoint1          4170.31         5.03            -             -       4160.4       4180.2
# ----------------------------------------------------------------------------------------------------
# These alphas(gradients of segments) are estimatedfrom betas(change in gradient)
# ----------------------------------------------------------------------------------------------------
# alpha2            0.00150726     1.31e-05       114.81           0.0    0.0014815     0.001533
# ====================================================================================================
# Davies test for existence of at least 1 breakpoint: p=0.0 (e.g. p<0.05 means reject null hypothesis of no breakpoints at 5% significance)
# '\n                    Breakpoint Regression Results                     \n====================================================================================================\nNo. Observations                     5073\nNo. Model Parameters                    4\nDegrees of Freedom                   5069\nRes. Sum of Squares               53.4328\nTotal Sum of Squares              555.791\nR Squared                        0.903862\nAdjusted R Squared               0.903786\nConverged:                           True\n====================================================================================================\n====================================================================================================\n                    Estimate      Std Err            t        P>|t|       [0.025       0.975]\n----------------------------------------------------------------------------------------------------\nconst                1.07827      0.00318        339.2           0.0        1.072       1.0845\nalpha1           9.33084e-06     1.32e-06       7.0672       1.8e-12   6.7425e-06   1.1919e-05\nbeta1             0.00149793     1.32e-05       113.52             -    0.0014721    0.0015238\nbreakpoint1          4170.31         5.03            -             -       4160.4       4180.2\n----------------------------------------------------------------------------------------------------\nThese alphas(gradients of segments) are estimatedfrom betas(change in gradient)\n----------------------------------------------------------------------------------------------------\nalpha2            0.00150726     1.31e-05       114.81           0.0    0.0014815     0.001533\n====================================================================================================\nDavies test for existence of at least 1 breakpoint: p=0.0 (e.g. p<0.05 means reject null hypothesis of no breakpoints at 5% significance)\n\n'

# %%
# The results of fitting
p1_res = p1_fit.get_results()
p1_estimates = p1_res["estimates"]

# Extract the results of fitting
p1_const = p1_estimates["const"]["estimate"]
p1_alpha_1 = p1_estimates["alpha1"]["estimate"]
p1_alpha_2 = p1_estimates["alpha2"]["estimate"]

p1_breakpoint = p1_estimates["breakpoint1"]["estimate"]
p1_breakpoint_errs = p1_estimates["breakpoint1"]["confidence_interval"]

# Construct lines to show on the plot
p1_line1 = indices_sel*p1_alpha_1 + p1_const
p1_line2 = indices_sel*p1_alpha_2 + np.nanmax(p1_line1) #- np.nanmax(ints_sel.values)

# %%
def generate_fit_lines(indices, const, alpha1, alpha2, breakpoint):
    """
    Generates two lines from fit parameters.
    
    Parameters:
    ----------
    indices : {array-like}
    const : {float}
    alpha1 : {float}
    alpha2 : {float}
    breakpoint : {float}

    Returns:
    --------
    line1 : {pd.Series} the first line until breakpoint.
    line2 : {pd.Series} the second line from breakpoint to first peak.
    """

    # Working with indices, the breaking point of the two lines must
    # be an integer
    bp_int = int(breakpoint)

    # For the first line just take indices from start to the breakpoint
    indices_sel1 = indices[:bp_int]

    # For the second part we need two sets of indices; one running from 0 -> len(indices2)
    # to calculate the values, and the latter part of indices itself to index the values.
    indices_sel2 = indices[bp_int:]
    num_indices2 = len(indices_sel2)

    line1 = indices_sel1 * alpha1 + const

    if alpha1 > 0:
        line2 = np.linspace(start=0, stop=num_indices2, num=num_indices2) * alpha2 + np.nanmax(line1)
    else:
        line2 = np.linspace(start=0, stop=num_indices2, num=num_indices2) * alpha2 - np.nanmax(line1)
    
    return pd.Series(line1, index=indices_sel1), pd.Series(line2, index=indices_sel2)

# %%
p1_line1, p1_line2 = generate_fit_lines(indices=indices_sel, const=p1_const,
                                       alpha1=p1_alpha_1, alpha2=p1_alpha_2,
                                       breakpoint=p1_breakpoint)

# %%
# Plot the fit results on the real data
ax2.plot(p1_line1.index, p1_line1.values, ls="--", c="navy")
ax2.plot(p1_line2.index, p1_line2.values, ls="--", c="navy")

ax2.axvspan(xmin=p1_breakpoint_errs[0], xmax=p1_breakpoint_errs[1], alpha=0.25, color="red")
ax2.axvline(x=p1_breakpoint, c="red")

fig2

# %%
# Finally find the onset time and related uncertainty
def get_interpolated_timestamp(datetimes, breakpoint):
    """
    Finds a timestamp from a series that relates to a floating-point index rather than integer.

    Parameters:
    -----------
    datetimes : {DatetimeIndex or similar}
    breakpoint : {float}
    
    Returns:
    ----------
    interpolated_timestamp : {Timestamp}
    """

    # The "floor" of the index
    lower_index = int(breakpoint)
    fractional_part = breakpoint - lower_index

    # gets the two timestamps to interpolate between
    lower_timestamp = datetimes[lower_index]
    upper_timestamp = datetimes[lower_index+1]

    # Calculate the interpolated timestamp
    interpolated_timestamp = lower_timestamp + fractional_part * (upper_timestamp - lower_timestamp)

    return interpolated_timestamp


onset_time = get_interpolated_timestamp(datetimes=filled_ints.index, breakpoint=p1_breakpoint)
print(onset_time)
# Out:
# 2023-03-13 03:48:07.441999155

# %%
ax1.axvline(x=onset_time, c="red")

fig1

# %%
# Next step is to generalize the workflow; resampling should be possible prior to fitting

# %%
# Workflow:
# 1) Choose resampling or None for data
# 2) Choose a selection from start of background to first peak
# 3) run break_regression()

# %%
def workflow(data, channel:str, resample:str=None, xlim:list=None, fill_style:str="bfill",
            window:int=None ,threshold:float=None, plot:bool=True):
    """

    Parameters:
    -----------
    data : {pd.DataFrame}
    channel : {str}
    resample : {str}
    xlim : {list}
    fill_style : {str}
    window : {str}
    threshold : {float}
    plot : {bool}
    """
    FIGSIZE = (13,7)

    # Choose resampling:
    if isinstance(resample, str):
        data = resample_df(df=data, avg=resample)
    # If no resampling, just take a copy of the original data to avert 
    # modifying it by accident
    else:
        data = data.copy(deep=True)

    # Choose channel
    series = data[channel]

    # Convert to log
    series = calc.ints2log10(intensity=series, fill_style=fill_style)

    # Get the numerical index of the first peak to choose the selection from 
    # background to first peak. Also generate numerical index to run from 0 to max_idx
    max_val, max_idx = calc.search_first_peak(ints=series, window=window, threshold=threshold)

    series = series[:max_idx]
    numerical_indices = np.linspace(start=0, stop=max_idx, num=max_idx)

    # Get the fit results
    fit_results = break_regression(ints=series.values, indices=numerical_indices)

    # The results are a dictionary, extract values here
    estimates = fit_results["estimates"]

    const = estimates["const"]["estimate"]
    alpha1 = estimates["alpha1"]["estimate"]
    alpha2 = estimates["alpha2"]["estimate"]
    
    break_point = estimates["breakpoint1"]["estimate"]
    break_point_errs = estimates["breakpoint1"]["confidence_interval"]

    if plot:
        # Generate the fit lines to display on the plot
        line1, line2 = calc.generate_fit_lines(indices=numerical_indices, const=const,
                                               alpha1=alpha1, alpha2=alpha2, break_point=break_point)

        # Init figure
        fig, ax = plt.subplots(figsize=FIGSIZE)

        # Plot the intensities
        ax.step(numerical_indices, series.values)

        # Plot the fit results on the real data
        ax.plot(line1.index, line1.values, ls="--", c="navy")
        ax.plot(line2.index, line2.values, ls="--", c="navy")
        
        ax.axvspan(xmin=break_point_errs[0], xmax=break_point_errs[1], alpha=0.25, color="red")
        ax.axvline(x=break_point, c="red")

        plt.show()

    return [const, alpha1, alpha2, break_point, break_point_errs]

# %%
results = workflow(data=df, channel="P1", window=100, threshold=2)
# Out:
# /home/chospa/anaconda3/envs/regs/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
