# %% [markdown]
# @article{Pilgrim2021,
#          doi = {10.21105/joss.03859},
#          url = {https://doi.org/10.21105/joss.03859},
#          year = {2021}, publisher = {The Open Journal},
#          volume = {6},
#          number = {68},
#          pages = {3859},
#          author = {Charlie Pilgrim},
#          title = {piecewise-regression (aka segmented regression) in Python},
#          journal = {Journal of Open Source Software}
#         }

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import piecewise_regression

from reg import quicklook, break_regression


path = f"data{os.sep}"
filename = "phys_data_2023-03-12_side0.csv"

# %%
df = pd.read_csv(f"{path}{filename}", parse_dates=True, index_col="TimeUTC")

# %%
df
# Out:
#                        P1     P2    P3    P4     P5     P6     P7      P8  \
# TimeUTC
# 2023-03-12 00:00:00   0.0   0.00  0.00  0.00  0.000  0.000  0.000  0.0000
# 2023-03-12 00:00:24   0.0   0.00  0.00  0.00  0.000  0.000  0.000  0.0000
# 2023-03-12 00:00:48   0.0   0.00  0.00  0.00  0.000  0.000  0.000  0.0000
# 2023-03-12 00:01:12   0.0   0.00  0.00  0.00  0.000  0.000  0.000  0.0000
# 2023-03-12 00:01:36   0.0   0.00  0.00  0.00  0.000  0.000  0.000  0.0000
# ...                   ...    ...   ...   ...    ...    ...    ...     ...
# 2023-03-14 23:58:00  61.2   7.14  3.95  3.42  1.590  0.000  0.142  0.0671
# 2023-03-14 23:58:24  24.5  14.30  9.88  5.70  1.590  0.954  0.142  0.0671
# 2023-03-14 23:58:48  61.2  21.40  9.89  2.28  1.590  0.000  0.142  0.0671
# 2023-03-14 23:59:12  48.9  14.30  5.93  5.70  1.590  0.954  0.000  0.0671
# 2023-03-14 23:59:36  61.2   7.14  0.00  1.14  0.795  1.190  0.000  0.0000
#
#                          P9      E1      E2      E3     E4    E5     E6  \
# TimeUTC
# 2023-03-12 00:00:00  0.0000     0.0     0.0   11.40    0.0   0.0  0.000
# 2023-03-12 00:00:24  0.0144   167.0     0.0    7.58    0.0   0.0  0.000
# 2023-03-12 00:00:48  0.0000     0.0     0.0    0.00    0.0   0.0  0.627
# 2023-03-12 00:01:12  0.0000   112.0    17.6    0.00    0.0   0.0  0.313
# 2023-03-12 00:01:36  0.0000    55.8     0.0    0.00    0.0   0.0  0.000
# ...                     ...     ...     ...     ...    ...   ...    ...
# 2023-03-14 23:58:00  0.0144  7090.0  2200.0  865.00  325.0  10.5  0.314
# 2023-03-14 23:58:24  0.0000  5030.0  1920.0  819.00  309.0  21.0  0.000
# 2023-03-14 23:58:48  0.0000  6480.0  2360.0  895.00  262.0  16.8  0.314
# 2023-03-14 23:59:12  0.0000  6420.0  2390.0  895.00  325.0  14.7  0.000
# 2023-03-14 23:59:36  0.0000  6700.0  1810.0  827.00  325.0  23.1  0.627
#
#                         E7    DT          PA
# TimeUTC
# 2023-03-12 00:00:00  0.000  0.00   86.490453
# 2023-03-12 00:00:24  0.000  0.00   81.321720
# 2023-03-12 00:00:48  0.000  0.00   69.690026
# 2023-03-12 00:01:12  0.000  0.00   70.727876
# 2023-03-12 00:01:36  0.000  0.00   68.520445
# ...                    ...   ...         ...
# 2023-03-14 23:58:00  0.000  1.29  100.899747
# 2023-03-14 23:58:24  0.088  1.12   84.530333
# 2023-03-14 23:58:48  0.000  1.46   95.456014
# 2023-03-14 23:59:12  0.000  1.29  101.019541
# 2023-03-14 23:59:36  0.000  1.17  107.450316
#
# [10800 rows x 18 columns]

# %%
quicklook(data=df, channel="P1", resample="1 min")

# %% [markdown]
# ### piecewise-regression testing:

# %%
# The slope of the first line
alpha_1 = 0.5

# The slope of the second line
alpha_2 = 7

# The constant factor of the first line alpha_1 * x + C
constant = 12

# The point at which the gradient changes from alpha_1 to alpha_2
breakpoint_1 = 11

# The number of data points in consideration
n_points = 2000

# Setting the random seed for reproductibility
np.random.seed(0)

# The x-axis values, i.e., the independent variable
xx = np.linspace(0, 20, n_points)

# The dependent variable
yy = constant + alpha_1*xx + (alpha_2-alpha_1) * np.maximum(xx - breakpoint_1, 0) + np.random.normal(size=n_points)

# %%
# Prepare the figure visualizing the data
fig, ax = plt.subplots(figsize=(13,7))

ax.step(xx,yy, where="mid", c="grey")
#ax.scatter(xx,yy)

plt.show()

# %%
# Given some data, fit the model
pw_fit = piecewise_regression.Fit(xx, yy, start_values=[5], n_breakpoints=1)

# Print a summary of the fit
pw_fit.summary()
# Out:
#                     Breakpoint Regression Results
# ====================================================================================================
# No. Observations                     2000
# No. Model Parameters                    4
# Degrees of Freedom                   1996
# Res. Sum of Squares               1910.35
# Total Sum of Squares          8.84751e+05
# R Squared                        0.997841
# Adjusted R Squared               0.997836
# Converged:                           True
# ====================================================================================================
# ====================================================================================================
#                     Estimate      Std Err            t        P>|t|       [0.025       0.975]
# ----------------------------------------------------------------------------------------------------
# const                11.9589        0.059       202.67           0.0       11.843       12.075
# alpha1              0.499759      0.00931        53.68           0.0       0.4815      0.51802
# beta1                6.48542       0.0156       416.02             -       6.4548        6.516
# breakpoint1          10.9804       0.0136            -             -       10.954       11.007
# ----------------------------------------------------------------------------------------------------
# These alphas(gradients of segments) are estimatedfrom betas(change in gradient)
# ----------------------------------------------------------------------------------------------------
# alpha2               6.98518       0.0125       558.65           0.0       6.9607       7.0097
# ====================================================================================================
# Davies test for existence of at least 1 breakpoint: p=0.0 (e.g. p<0.05 means reject null hypothesis of no breakpoints at 5% significance)
# '\n                    Breakpoint Regression Results                     \n====================================================================================================\nNo. Observations                     2000\nNo. Model Parameters                    4\nDegrees of Freedom                   1996\nRes. Sum of Squares               1910.35\nTotal Sum of Squares          8.84751e+05\nR Squared                        0.997841\nAdjusted R Squared               0.997836\nConverged:                           True\n====================================================================================================\n====================================================================================================\n                    Estimate      Std Err            t        P>|t|       [0.025       0.975]\n----------------------------------------------------------------------------------------------------\nconst                11.9589        0.059       202.67           0.0       11.843       12.075\nalpha1              0.499759      0.00931        53.68           0.0       0.4815      0.51802\nbeta1                6.48542       0.0156       416.02             -       6.4548        6.516\nbreakpoint1          10.9804       0.0136            -             -       10.954       11.007\n----------------------------------------------------------------------------------------------------\nThese alphas(gradients of segments) are estimatedfrom betas(change in gradient)\n----------------------------------------------------------------------------------------------------\nalpha2               6.98518       0.0125       558.65           0.0       6.9607       7.0097\n====================================================================================================\nDavies test for existence of at least 1 breakpoint: p=0.0 (e.g. p<0.05 means reject null hypothesis of no breakpoints at 5% significance)\n\n'

# %%
# Get the key results of the fit
pw_results = pw_fit.get_results()
pw_estimates = pw_results["estimates"]

# %%
pw_results
# Out:
# {'davies': 0.0,
#  'estimates': {'const': {'estimate': 11.95892145068034,
#    'se': 0.059007610826463185,
#    'confidence_interval': (11.84319848553212, 12.074644415828558),
#    't_stat': 202.66744040613,
#    'p_t': 0.0},
#   'beta1': {'estimate': 6.485421536556528,
#    'se': 0.01558903155915342,
#    'confidence_interval': (6.454849057336519, 6.515994015776537),
#    't_stat': 416.0246588729548,
#    'p_t': '-'},
#   'breakpoint1': {'estimate': 10.980420870967645,
#    'se': 0.013557487007679007,
#    'confidence_interval': (10.953832561857807, 11.007009180077484),
#    't_stat': '-',
#    'p_t': '-'},
#   'alpha1': {'estimate': 0.4997592260207653,
#    'se': 0.00930991848222239,
#    'confidence_interval': (0.4815010495421506, 0.5180174024993799),
#    't_stat': 53.68030095806668,
#    'p_t': 0.0},
#   'alpha2': {'estimate': 6.9851807625772935,
#    'se': 0.012503732355047243,
#    'confidence_interval': (6.960659027782756, 7.009702497371831),
#    't_stat': 558.6476552945139,
#    'p_t': 0.0}},
#  'bic': -61.32164004391645,
#  'rss': 1910.3463402974435,
#  'converged': True}

# %%
pw_estimates
# Out:
# {'const': {'estimate': 11.95892145068034,
#   'se': 0.059007610826463185,
#   'confidence_interval': (11.84319848553212, 12.074644415828558),
#   't_stat': 202.66744040613,
#   'p_t': 0.0},
#  'beta1': {'estimate': 6.485421536556528,
#   'se': 0.01558903155915342,
#   'confidence_interval': (6.454849057336519, 6.515994015776537),
#   't_stat': 416.0246588729548,
#   'p_t': '-'},
#  'breakpoint1': {'estimate': 10.980420870967645,
#   'se': 0.013557487007679007,
#   'confidence_interval': (10.953832561857807, 11.007009180077484),
#   't_stat': '-',
#   'p_t': '-'},
#  'alpha1': {'estimate': 0.4997592260207653,
#   'se': 0.00930991848222239,
#   'confidence_interval': (0.4815010495421506, 0.5180174024993799),
#   't_stat': 53.68030095806668,
#   'p_t': 0.0},
#  'alpha2': {'estimate': 6.9851807625772935,
#   'se': 0.012503732355047243,
#   'confidence_interval': (6.960659027782756, 7.009702497371831),
#   't_stat': 558.6476552945139,
#   'p_t': 0.0}}

# %%
# Extract the results of fitting
estimated_const = pw_estimates["const"]["estimate"]
estimated_alpha_1 = pw_estimates["alpha1"]["estimate"]
estimated_alpha_2 = pw_estimates["alpha2"]["estimate"]

estimated_breakpoint = pw_estimates["breakpoint1"]["estimate"]
breakpoint_errs = pw_estimates["breakpoint1"]["confidence_interval"]

# %%
# Construct lines to show on the plot
line1 = xx*estimated_alpha_1 + estimated_const
line2 = xx*estimated_alpha_2 + np.nanmax(line1) - np.nanmax(yy)

# %%
# Plot the estimated values
ax.plot(xx, line1, ls="--", c="navy")
ax.plot(xx, line2, ls="--", c="navy")

ax.axvspan(xmin=breakpoint_errs[0], xmax=breakpoint_errs[1], alpha=0.25, color="red")
ax.axvline(x=estimated_breakpoint, c="red")

fig

# %%
ax.set_xlim(10,12)
fig

# %%
# Try the same but now with the P1 channel of previously downloaded data

# %%
def search_first_peak(ints, window=None):
    """
    Searches for a local maximum for a given window.
    """
    
    if window is None:
        window = 30

    threshold = -1e5
    warnings = 0
    for idx, val in enumerate(ints):
        
        if val > threshold:
            val = threshold
            warnings = 0
        else:
            warnings += 1
        
        if warnings == window:
            max_idx = idx-window
            return val, max_idx
    
    return False, False

# %%
# Intensities of P1 channel
ints = np.log10(df["P1"].values)
times = df.index.values
indices = np.linspace(start=0, stop=len(times)-1, num=len(times))
# Out:
# <ipython-input-55-619989919557>:2: RuntimeWarning: divide by zero encountered in log10
#   ints = np.log10(df["P1"].values)

# %%
ints
# Out:
# array([      -inf,       -inf,       -inf, ..., 1.78675142, 1.68930886,
#        1.78675142])

# %%
kek = -np.inf
np.isnan(kek)
# Out:
# False

# %%
first_peak, first_peak_idx = search_first_peak(ints=ints)
print(first_peak)
print(first_peak_idx)
# Out:
# -inf
# 22

# %%
fig1, ax1 = plt.subplots(figsize=(13,7))

ax1.step(times, ints)

ax1.axvspan(xmin=times[0], xmax=times[first_peak_idx], alpha=0.08, color="limegreen")

plt.show()

# %%
# Fit the model
p1_fit = piecewise_regression.Fit(indices, ints, start_values=[5], n_breakpoints=1)

# Print a summary of the fit
p1_fit.summary()
# Out:
# Algorithm did not converge. Try different n_breakpoints, different start_values, or start_values=None
# Summary of why the algorithm did not converge:
# Run 1: Error encountered: exog contains inf or nans
# Run 2: Error encountered: exog contains inf or nans
# Run 3: Error encountered: exog contains inf or nans
# Run 4: Error encountered: exog contains inf or nans
# Run 5: Error encountered: exog contains inf or nans
# Run 6: Error encountered: exog contains inf or nans
# Run 7: Error encountered: exog contains inf or nans
# Run 8: Error encountered: exog contains inf or nans
# Run 9: Error encountered: exog contains inf or nans
# Run 10: Error encountered: exog contains inf or nans
# Run 11: Error encountered: exog contains inf or nans
# Run 12: Error encountered: exog contains inf or nans
# Run 13: Error encountered: exog contains inf or nans
# Run 14: Error encountered: exog contains inf or nans
# Run 15: Error encountered: exog contains inf or nans
# Run 16: Error encountered: exog contains inf or nans
# Run 17: Error encountered: exog contains inf or nans
# Run 18: Error encountered: exog contains inf or nans
# Run 19: Error encountered: exog contains inf or nans
# Run 20: Error encountered: exog contains inf or nans
# Run 21: Error encountered: exog contains inf or nans
# Run 22: Error encountered: exog contains inf or nans
# Run 23: Error encountered: exog contains inf or nans
# Run 24: Error encountered: exog contains inf or nans
# Run 25: Error encountered: exog contains inf or nans
# Run 26: Error encountered: exog contains inf or nans
# Run 27: Error encountered: exog contains inf or nans
# Run 28: Error encountered: exog contains inf or nans
# Run 29: Error encountered: exog contains inf or nans
# Run 30: Error encountered: exog contains inf or nans
# Run 31: Error encountered: exog contains inf or nans
# Run 32: Error encountered: exog contains inf or nans
# Run 33: Error encountered: exog contains inf or nans
# Run 34: Error encountered: exog contains inf or nans
# Run 35: Error encountered: exog contains inf or nans
# Run 36: Error encountered: exog contains inf or nans
# Run 37: Error encountered: exog contains inf or nans
# Run 38: Error encountered: exog contains inf or nans
# Run 39: Error encountered: exog contains inf or nans
# Run 40: Error encountered: exog contains inf or nans
# Run 41: Error encountered: exog contains inf or nans
# Run 42: Error encountered: exog contains inf or nans
# Run 43: Error encountered: exog contains inf or nans
# Run 44: Error encountered: exog contains inf or nans
# Run 45: Error encountered: exog contains inf or nans
# Run 46: Error encountered: exog contains inf or nans
# Run 47: Error encountered: exog contains inf or nans
# Run 48: Error encountered: exog contains inf or nans
# Run 49: Error encountered: exog contains inf or nans
# Run 50: Error encountered: exog contains inf or nans
# Run 51: Error encountered: exog contains inf or nans
# Run 52: Error encountered: exog contains inf or nans
# Run 53: Error encountered: exog contains inf or nans
# Run 54: Error encountered: exog contains inf or nans
# Run 55: Error encountered: exog contains inf or nans
# Run 56: Error encountered: exog contains inf or nans
# Run 57: Error encountered: exog contains inf or nans
# Run 58: Error encountered: exog contains inf or nans
# Run 59: Error encountered: exog contains inf or nans
# Run 60: Error encountered: exog contains inf or nans
# Run 61: Error encountered: exog contains inf or nans
# Run 62: Error encountered: exog contains inf or nans
# Run 63: Error encountered: exog contains inf or nans
# Run 64: Error encountered: exog contains inf or nans
# Run 65: Error encountered: exog contains inf or nans
# Run 66: Error encountered: exog contains inf or nans
# Run 67: Error encountered: exog contains inf or nans
# Run 68: Error encountered: exog contains inf or nans
# Run 69: Error encountered: exog contains inf or nans
# Run 70: Error encountered: exog contains inf or nans
# Run 71: Error encountered: exog contains inf or nans
# Run 72: Error encountered: exog contains inf or nans
# Run 73: Error encountered: exog contains inf or nans
# Run 74: Error encountered: exog contains inf or nans
# Run 75: Error encountered: exog contains inf or nans
# Run 76: Error encountered: exog contains inf or nans
# Run 77: Error encountered: exog contains inf or nans
# Run 78: Error encountered: exog contains inf or nans
# Run 79: Error encountered: exog contains inf or nans
# Run 80: Error encountered: exog contains inf or nans
# Run 81: Error encountered: exog contains inf or nans
# Run 82: Error encountered: exog contains inf or nans
# Run 83: Error encountered: exog contains inf or nans
# Run 84: Error encountered: exog contains inf or nans
# Run 85: Error encountered: exog contains inf or nans
# Run 86: Error encountered: exog contains inf or nans
# Run 87: Error encountered: exog contains inf or nans
# Run 88: Error encountered: exog contains inf or nans
# Run 89: Error encountered: exog contains inf or nans
# Run 90: Error encountered: exog contains inf or nans
# Run 91: Error encountered: exog contains inf or nans
# Run 92: Error encountered: exog contains inf or nans
# Run 93: Error encountered: exog contains inf or nans
# Run 94: Error encountered: exog contains inf or nans
# Run 95: Error encountered: exog contains inf or nans
# Run 96: Error encountered: exog contains inf or nans
# Run 97: Error encountered: exog contains inf or nans
# Run 98: Error encountered: exog contains inf or nans
# Run 99: Error encountered: exog contains inf or nans
# Run 100: Error encountered: exog contains inf or nans
# Run 101: Error encountered: exog contains inf or nans
# 'Algorithm did not converge. Try different n_breakpoints, different start_values, or start_values=None\nSummary of why the algorithm did not converge:\nRun 1: Error encountered: exog contains inf or nans \nRun 2: Error encountered: exog contains inf or nans \nRun 3: Error encountered: exog contains inf or nans \nRun 4: Error encountered: exog contains inf or nans \nRun 5: Error encountered: exog contains inf or nans \nRun 6: Error encountered: exog contains inf or nans \nRun 7: Error encountered: exog contains inf or nans \nRun 8: Error encountered: exog contains inf or nans \nRun 9: Error encountered: exog contains inf or nans \nRun 10: Error encountered: exog contains inf or nans \nRun 11: Error encountered: exog contains inf or nans \nRun 12: Error encountered: exog contains inf or nans \nRun 13: Error encountered: exog contains inf or nans \nRun 14: Error encountered: exog contains inf or nans \nRun 15: Error encountered: exog contains inf or nans \nRun 16: Error encountered: exog contains inf or nans \nRun 17: Error encountered: exog contains inf or nans \nRun 18: Error encountered: exog contains inf or nans \nRun 19: Error encountered: exog contains inf or nans \nRun 20: Error encountered: exog contains inf or nans \nRun 21: Error encountered: exog contains inf or nans \nRun 22: Error encountered: exog contains inf or nans \nRun 23: Error encountered: exog contains inf or nans \nRun 24: Error encountered: exog contains inf or nans \nRun 25: Error encountered: exog contains inf or nans \nRun 26: Error encountered: exog contains inf or nans \nRun 27: Error encountered: exog contains inf or nans \nRun 28: Error encountered: exog contains inf or nans \nRun 29: Error encountered: exog contains inf or nans \nRun 30: Error encountered: exog contains inf or nans \nRun 31: Error encountered: exog contains inf or nans \nRun 32: Error encountered: exog contains inf or nans \nRun 33: Error encountered: exog contains inf or nans \nRun 34: Error encountered: exog contains inf or nans \nRun 35: Error encountered: exog contains inf or nans \nRun 36: Error encountered: exog contains inf or nans \nRun 37: Error encountered: exog contains inf or nans \nRun 38: Error encountered: exog contains inf or nans \nRun 39: Error encountered: exog contains inf or nans \nRun 40: Error encountered: exog contains inf or nans \nRun 41: Error encountered: exog contains inf or nans \nRun 42: Error encountered: exog contains inf or nans \nRun 43: Error encountered: exog contains inf or nans \nRun 44: Error encountered: exog contains inf or nans \nRun 45: Error encountered: exog contains inf or nans \nRun 46: Error encountered: exog contains inf or nans \nRun 47: Error encountered: exog contains inf or nans \nRun 48: Error encountered: exog contains inf or nans \nRun 49: Error encountered: exog contains inf or nans \nRun 50: Error encountered: exog contains inf or nans \nRun 51: Error encountered: exog contains inf or nans \nRun 52: Error encountered: exog contains inf or nans \nRun 53: Error encountered: exog contains inf or nans \nRun 54: Error encountered: exog contains inf or nans \nRun 55: Error encountered: exog contains inf or nans \nRun 56: Error encountered: exog contains inf or nans \nRun 57: Error encountered: exog contains inf or nans \nRun 58: Error encountered: exog contains inf or nans \nRun 59: Error encountered: exog contains inf or nans \nRun 60: Error encountered: exog contains inf or nans \nRun 61: Error encountered: exog contains inf or nans \nRun 62: Error encountered: exog contains inf or nans \nRun 63: Error encountered: exog contains inf or nans \nRun 64: Error encountered: exog contains inf or nans \nRun 65: Error encountered: exog contains inf or nans \nRun 66: Error encountered: exog contains inf or nans \nRun 67: Error encountered: exog contains inf or nans \nRun 68: Error encountered: exog contains inf or nans \nRun 69: Error encountered: exog contains inf or nans \nRun 70: Error encountered: exog contains inf or nans \nRun 71: ...
